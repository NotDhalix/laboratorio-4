# %%
#Puntos de iteracción en el programa

#UTP 9.022156086139319, -79.5320311052507

#Estación San Miguelito 9.03008105258303, -79.50648707796248

#El Dorado Mall 9.009159705986622, -79.53581012377204

#Albrook Mall 8.970621048117671, -79.55295111656532

#AltaPlaza Mall 9.029349178421912, -79.53450087423582

#Estadio Rod Carew 9.040778100106364, -79.5458333030321

#Parque Urracá 8.975322758417006, -79.52819595484729

#PriceSmart 9.015167561733548, -79.53693902996527

#Sertracen 9.027774919254423, -79.48250019739038

#Artec 9.034525004736638, -79.51200604061219

#UTP sede de Tocumen 9.066997315174145, -79.40528368772904

# %%
import folium
from folium.plugins import MiniMap

# %%
texto1="<b>UTP</b>"
texto2="<b>Estacion San Miguelito</b>"
texto3="<b>El Dorado Mall</b>"
texto4="<b>Terminal Albrook Mall</b>"
texto5="<b>AltaPlaza Mall</b>"
texto6="<b>Estadio Rod Carew</b>"
texto7="<b>Parque Urrracá</b>"
texto8="<b>PriceSmart</b>"
texto9="<b>Sertracen</b>"
texto10="<b>Artec</b>"
texto11="<b>UTP sede de Tocumen</b>"
texto12="<b>MiBus   M181   M530    M675</b>"
#Iniciación del mapa
utp_map = folium.Map(location=[9.022156086139319, -79.5320311052507],zoom_start=16)

#localización utp
folium.Marker(location=[9.022261542758255, -79.53257480417845],popup=texto1).add_to(utp_map)

#Locacalización Estación San Miguelito
folium.Marker(location=[9.03018003353083, -79.50648770273543],popup=texto2).add_to(utp_map)

#Localización El Dorado Mall
folium.Marker(location=[9.009411551422904, -79.53597679192606],popup=texto3).add_to(utp_map)

#Localización Albrook Mall
folium.Marker(location=[8.970621048117671, -79.55295111656532],popup=texto4).add_to(utp_map)

#Localización AltaPlaza Mall
folium.Marker(location=[9.030255214134929, -79.53391124844335],popup=texto5).add_to(utp_map)

#Localización Estadio Rod Carew
folium.Marker(location=[9.040778100106364, -79.5458333030321],popup=texto6).add_to(utp_map)

#Localización Parque Urracá
folium.Marker(location=[8.975322758417006, -79.52819595484729],popup=texto7).add_to(utp_map)

#Localización PriceSmart
folium.Marker(location=[9.015167561733548, -79.53693902996527],popup=texto8).add_to(utp_map)

#Localización Sertracen 
folium.Marker(location=[9.027774919254423, -79.48250019739038],popup=texto9).add_to(utp_map)

#Localización Artec
folium.Marker(location=[9.034525004736638, -79.51200604061219],popup=texto10).add_to(utp_map)

#Localización UTP sede Tocumen
folium.Marker(location=[9.06774261795484, -79.40545806231057],popup=texto11).add_to(utp_map)

#Paradas
folium.Marker(location=[9.021165948189683, -79.52956104644753],popup=texto12).add_to(utp_map)

minimap = MiniMap()

utp_map.add_child(minimap)
utp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3aa502cbbd38b227fdb2e771369bcd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3aa502cbbd38b227fdb2e771369bcd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3aa502cbbd38b227fdb2e771369bcd9 = L.map(
#                 &quot;map_b3aa502cbbd38b227fdb2e771369bcd9&quot;,
#                 {
#                     center: [9.022156086139319, -79.5320311052507],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfd4acf713a2d947b3780d8fa66f6127 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b3aa502cbbd38b227fdb2e771369bcd9);
#
#
#             var marker_65f268c1792625f7c2833a4ca8504ee7 = L.marker(
#                 [9.022261542758255, -79.53257480417845],
#                 {}
#             ).addTo(map_b3aa502cbbd38b227fdb2e771369bcd9);
#
#
#         var popup_d33223a74e1a7197f81943848e0e2bdf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb9062d2ec0d8d066e23e786ed40c86c = $(`&lt;div id=&quot;html_bb9062d2ec0d8d066e23e786ed40c86c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;UTP&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_d33223a74e1a7197f81943848e0e2bdf.setContent(html_bb9062d2ec0d8d066e23e786ed40c86c);
#
#
#
#         marker_65f268c1792625f7c2833a4ca8504ee7.bindPopup(popup_d33223a74e1a7197f81943848e0e2bdf)
#         ;
#
#
#
#
#             var marker_e9e6684f8225efa5aeec667281afad72 = L.marker(
#                 [9.03018003353083, -79.50648770273543],
#                 {}
#             ).addTo(map_b3aa502cbbd38b227fdb2e771369bcd9);
#
#
#         var popup_cfe472609386df1a266fd740a05b9d12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3374503b5869e11fa46e1153f1c31cb5 = $(`&lt;div id=&quot;html_3374503b5869e11fa46e1153f1c31cb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Estacion San Miguelito&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_cfe472609386df1a266fd740a05b9d12.setContent(html_3374503b5869e11fa46e1153f1c31cb5);
#
#
#
#         marker_e9e6684f8225efa5aeec667281afad72.bindPopup(popup_cfe472609386df1a266fd740a05b9d12)
#         ;
#
#
#
#
#             var marker_f2d93ceb2c8af71a969d38f5ce131226 = L.marker(
#                 [9.009411551422904, -79.53597679192606],
#                 {}
#             ).addTo(map_b3aa502cbbd38b227fdb2e771369bcd9);
#
#
#         var popup_70439459b547e5d07d7fc4a7d3eb4f35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e704e2a41c6dcd003a169083a25c1536 = $(`&lt;div id=&quot;html_e704e2a41c6dcd003a169083a25c1536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;El Dorado Mall&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_70439459b547e5d07d7fc4a7d3eb4f35.setContent(html_e704e2a41c6dcd003a169083a25c1536);
#
#
#
#         marker_f2d93ceb2c8af71a969d38f5ce131226.bindPopup(popup_70439459b547e5d07d7fc4a7d3eb4f35)
#         ;
#
#
#
#
#             var marker_970ac629491e51642d0d21bfc1f46d17 = L.marker(
#                 [8.970621048117671, -79.55295111656532],
#                 {}
#             ).addTo(map_b3aa502cbbd38b227fdb2e771369bcd9);
#
#
#         var popup_affb98cd459de3431e873f871948d9d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a71efaa66590849424edfbec928645e = $(`&lt;div id=&quot;html_7a71efaa66590849424edfbec928645e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Terminal Albrook Mall&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_affb98cd459de3431e873f871948d9d1.setContent(html_7a71efaa66590849424edfbec928645e);
#
#
#
#         marker_970ac629491e51642d0d21bfc1f46d17.bindPopup(popup_affb98cd459de3431e873f871948d9d1)
#         ;
#
#
#
#
#             var marker_1a703ff465848833af4ae3cc3a469be4 = L.marker(
#                 [9.030255214134929, -79.53391124844335],
#                 {}
#             ).addTo(map_b3aa502cbbd38b227fdb2e771369bcd9);
#
#
#         var popup_1b2700f35c120a13bf0e59ba93821856 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a15888b7d1ff3c7ae51fcec851f5b7b = $(`&lt;div id=&quot;html_1a15888b7d1ff3c7ae51fcec851f5b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;AltaPlaza Mall&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_1b27
